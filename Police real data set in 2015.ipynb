# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# 'C:\\Users\\khali_000'

# %%
police = pd.read_csv('C:\\Users\\khali_000\\Desktop\\PD.csv')

# %%
police
# Out:
#        stop_date    stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005   1:55:00 AM           NaN             M          1985.0
# 1      1/18/2005   8:15:00 AM           NaN             M          1965.0
# 2      1/23/2005  11:15:00 PM           NaN             M          1972.0
# 3      2/20/2005   5:15:00 PM           NaN             M          1986.0
# 4      3/14/2005  10:00:00 AM           NaN             F          1984.0
# ...          ...          ...           ...           ...             ...
# 65529  12/6/2012   5:54:00 PM           NaN             F          1987.0
# 65530  12/6/2012  10:22:00 PM           NaN             M          1954.0
# 65531  12/6/2012  11:20:00 PM           NaN             M          1985.0
# 65532  12/7/2012  12:23:00 AM           NaN           NaN             NaN
# 65533  12/7/2012  12:30:00 AM           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# 0            20.0       White                        Speeding   Speeding
# 1            40.0       White                        Speeding   Speeding
# 2            33.0       White                        Speeding   Speeding
# 3            19.0       White                Call for Service      Other
# 4            21.0       White                        Speeding   Speeding
# ...           ...         ...                             ...        ...
# 65529        25.0       White                        Speeding   Speeding
# 65530        58.0       White                        Speeding   Speeding
# 65531        27.0       Black  Equipment/Inspection Violation  Equipment
# 65532         NaN         NaN                             NaN        NaN
# 65533        27.0       White                        Speeding   Speeding
#
#        search_conducted search_type   stop_outcome is_arrested stop_duration  \
# 0                 False         NaN       Citation       False      0-15 Min
# 1                 False         NaN       Citation       False      0-15 Min
# 2                 False         NaN       Citation       False      0-15 Min
# 3                 False         NaN  Arrest Driver        True     16-30 Min
# 4                 False         NaN       Citation       False      0-15 Min
# ...                 ...         ...            ...         ...           ...
# 65529             False         NaN       Citation       False      0-15 Min
# 65530             False         NaN        Warning       False      0-15 Min
# 65531             False         NaN       Citation       False      0-15 Min
# 65532             False         NaN            NaN         NaN           NaN
# 65533             False         NaN       Citation       False      0-15 Min
#
#        drugs_related_stop
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 65529               False
# 65530               False
# 65531               False
# 65532               False
# 65533               False
#
# [65534 rows x 15 columns]

# %%
police.head()
# Out:
#    stop_date    stop_time  country_name driver_gender  driver_age_raw  \
# 0   1/2/2005   1:55:00 AM           NaN             M          1985.0
# 1  1/18/2005   8:15:00 AM           NaN             M          1965.0
# 2  1/23/2005  11:15:00 PM           NaN             M          1972.0
# 3  2/20/2005   5:15:00 PM           NaN             M          1986.0
# 4  3/14/2005  10:00:00 AM           NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# 0         NaN       Citation       False      0-15 Min               False
# 1         NaN       Citation       False      0-15 Min               False
# 2         NaN       Citation       False      0-15 Min               False
# 3         NaN  Arrest Driver        True     16-30 Min               False
# 4         NaN       Citation       False      0-15 Min               False

# %%
police.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          65534
# driver_gender          4060
# driver_age_raw         4053
# driver_age             4306
# driver_race            4059
# violation_raw          4059
# violation              4059
# search_conducted          0
# search_type           63055
# stop_outcome           4059
# is_arrested            4059
# stop_duration          4059
# drugs_related_stop        0
# dtype: int64

# %%
police.drop( columns = 'country_name')
# Out:
#        stop_date    stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005   1:55:00 AM             M          1985.0        20.0
# 1      1/18/2005   8:15:00 AM             M          1965.0        40.0
# 2      1/23/2005  11:15:00 PM             M          1972.0        33.0
# 3      2/20/2005   5:15:00 PM             M          1986.0        19.0
# 4      3/14/2005  10:00:00 AM             F          1984.0        21.0
# ...          ...          ...           ...             ...         ...
# 65529  12/6/2012   5:54:00 PM             F          1987.0        25.0
# 65530  12/6/2012  10:22:00 PM             M          1954.0        58.0
# 65531  12/6/2012  11:20:00 PM             M          1985.0        27.0
# 65532  12/7/2012  12:23:00 AM           NaN             NaN         NaN
# 65533  12/7/2012  12:30:00 AM             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# 1           White                        Speeding   Speeding
# 2           White                        Speeding   Speeding
# 3           White                Call for Service      Other
# 4           White                        Speeding   Speeding
# ...           ...                             ...        ...
# 65529       White                        Speeding   Speeding
# 65530       White                        Speeding   Speeding
# 65531       Black  Equipment/Inspection Violation  Equipment
# 65532         NaN                             NaN        NaN
# 65533       White                        Speeding   Speeding
#
#        search_conducted search_type   stop_outcome is_arrested stop_duration  \
# 0                 False         NaN       Citation       False      0-15 Min
# 1                 False         NaN       Citation       False      0-15 Min
# 2                 False         NaN       Citation       False      0-15 Min
# 3                 False         NaN  Arrest Driver        True     16-30 Min
# 4                 False         NaN       Citation       False      0-15 Min
# ...                 ...         ...            ...         ...           ...
# 65529             False         NaN       Citation       False      0-15 Min
# 65530             False         NaN        Warning       False      0-15 Min
# 65531             False         NaN       Citation       False      0-15 Min
# 65532             False         NaN            NaN         NaN           NaN
# 65533             False         NaN       Citation       False      0-15 Min
#
#        drugs_related_stop
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 65529               False
# 65530               False
# 65531               False
# 65532               False
# 65533               False
#
# [65534 rows x 14 columns]

# %%
police.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          65534
# driver_gender          4060
# driver_age_raw         4053
# driver_age             4306
# driver_race            4059
# violation_raw          4059
# violation              4059
# search_conducted          0
# search_type           63055
# stop_outcome           4059
# is_arrested            4059
# stop_duration          4059
# drugs_related_stop        0
# dtype: int64

# %%
police.drop( columns = 'country_name', inplace = True)

# %%
df
# Out:
#        stop_date    stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005   1:55:00 AM           NaN             M          1985.0
# 1      1/18/2005   8:15:00 AM           NaN             M          1965.0
# 2      1/23/2005  11:15:00 PM           NaN             M          1972.0
# 3      2/20/2005   5:15:00 PM           NaN             M          1986.0
# 4      3/14/2005  10:00:00 AM           NaN             F          1984.0
# ...          ...          ...           ...           ...             ...
# 65529  12/6/2012   5:54:00 PM           NaN             F          1987.0
# 65530  12/6/2012  10:22:00 PM           NaN             M          1954.0
# 65531  12/6/2012  11:20:00 PM           NaN             M          1985.0
# 65532  12/7/2012  12:23:00 AM           NaN           NaN             NaN
# 65533  12/7/2012  12:30:00 AM           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# 0            20.0       White                        Speeding   Speeding
# 1            40.0       White                        Speeding   Speeding
# 2            33.0       White                        Speeding   Speeding
# 3            19.0       White                Call for Service      Other
# 4            21.0       White                        Speeding   Speeding
# ...           ...         ...                             ...        ...
# 65529        25.0       White                        Speeding   Speeding
# 65530        58.0       White                        Speeding   Speeding
# 65531        27.0       Black  Equipment/Inspection Violation  Equipment
# 65532         NaN         NaN                             NaN        NaN
# 65533        27.0       White                        Speeding   Speeding
#
#        search_conducted search_type   stop_outcome is_arrested stop_duration  \
# 0                 False         NaN       Citation       False      0-15 Min
# 1                 False         NaN       Citation       False      0-15 Min
# 2                 False         NaN       Citation       False      0-15 Min
# 3                 False         NaN  Arrest Driver        True     16-30 Min
# 4                 False         NaN       Citation       False      0-15 Min
# ...                 ...         ...            ...         ...           ...
# 65529             False         NaN       Citation       False      0-15 Min
# 65530             False         NaN        Warning       False      0-15 Min
# 65531             False         NaN       Citation       False      0-15 Min
# 65532             False         NaN            NaN         NaN           NaN
# 65533             False         NaN       Citation       False      0-15 Min
#
#        drugs_related_stop
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 65529               False
# 65530               False
# 65531               False
# 65532               False
# 65533               False
#
# [65534 rows x 15 columns]

# %%
df.head()
# Out:
#    stop_date    stop_time  country_name driver_gender  driver_age_raw  \
# 0   1/2/2005   1:55:00 AM           NaN             M          1985.0
# 1  1/18/2005   8:15:00 AM           NaN             M          1965.0
# 2  1/23/2005  11:15:00 PM           NaN             M          1972.0
# 3  2/20/2005   5:15:00 PM           NaN             M          1986.0
# 4  3/14/2005  10:00:00 AM           NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# 0         NaN       Citation       False      0-15 Min               False
# 1         NaN       Citation       False      0-15 Min               False
# 2         NaN       Citation       False      0-15 Min               False
# 3         NaN  Arrest Driver        True     16-30 Min               False
# 4         NaN       Citation       False      0-15 Min               False

# %%
police[police.violation_raw == 'Speeding']
# Out:
#        stop_date    stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005   1:55:00 AM             M          1985.0        20.0
# 1      1/18/2005   8:15:00 AM             M          1965.0        40.0
# 2      1/23/2005  11:15:00 PM             M          1972.0        33.0
# 4      3/14/2005  10:00:00 AM             F          1984.0        21.0
# 6       4/1/2005   5:30:00 PM             M          1969.0        36.0
# ...          ...          ...           ...             ...         ...
# 65526  12/6/2012   3:26:00 PM             F          1981.0        31.0
# 65528  12/6/2012   4:00:00 PM             M          1994.0        18.0
# 65529  12/6/2012   5:54:00 PM             F          1987.0        25.0
# 65530  12/6/2012  10:22:00 PM             M          1954.0        58.0
# 65533  12/7/2012  12:30:00 AM             F          1985.0        27.0
#
#       driver_race violation_raw violation  search_conducted search_type  \
# 0           White      Speeding  Speeding             False         NaN
# 1           White      Speeding  Speeding             False         NaN
# 2           White      Speeding  Speeding             False         NaN
# 4           White      Speeding  Speeding             False         NaN
# 6           White      Speeding  Speeding             False         NaN
# ...           ...           ...       ...               ...         ...
# 65526       White      Speeding  Speeding             False         NaN
# 65528       White      Speeding  Speeding             False         NaN
# 65529       White      Speeding  Speeding             False         NaN
# 65530       White      Speeding  Speeding             False         NaN
# 65533       White      Speeding  Speeding             False         NaN
#
#       stop_outcome is_arrested stop_duration  drugs_related_stop
# 0         Citation       False      0-15 Min               False
# 1         Citation       False      0-15 Min               False
# 2         Citation       False      0-15 Min               False
# 4         Citation       False      0-15 Min               False
# 6         Citation       False      0-15 Min               False
# ...            ...         ...           ...                 ...
# 65526     Citation       False      0-15 Min               False
# 65528     Citation       False      0-15 Min               False
# 65529     Citation       False      0-15 Min               False
# 65530      Warning       False      0-15 Min               False
# 65533     Citation       False      0-15 Min               False
#
# [37204 rows x 14 columns]

# %%
police[police.violation_raw == 'Speeding'].driver_gender.value_counts()
# Out:
# M    25517
# F    11686
# Name: driver_gender, dtype: int64

# %%
df.head()
# Out:
#    stop_date    stop_time  country_name driver_gender  driver_age_raw  \
# 0   1/2/2005   1:55:00 AM           NaN             M          1985.0
# 1  1/18/2005   8:15:00 AM           NaN             M          1965.0
# 2  1/23/2005  11:15:00 PM           NaN             M          1972.0
# 3  2/20/2005   5:15:00 PM           NaN             M          1986.0
# 4  3/14/2005  10:00:00 AM           NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# 0         NaN       Citation       False      0-15 Min               False
# 1         NaN       Citation       False      0-15 Min               False
# 2         NaN       Citation       False      0-15 Min               False
# 3         NaN  Arrest Driver        True     16-30 Min               False
# 4         NaN       Citation       False      0-15 Min               False

# %%
police.groupby('driver_gender')

# %%
police.groupby('driver_gender').search_conducted.sum()
# Out:
# driver_gender
# F     366
# M    2113
# Name: search_conducted, dtype: int64

# %%
df.search_conducted.value_counts()
# Out:
# False    63055
# True      2479
# Name: search_conducted, dtype: int64

# %%
366 + 2113
# Out:
# 2479

# %%
2113 / 2479 *100
# Out:
# 85.23598225090763

# %%
df.stop_duration.value_counts()
# Out:
# 0-15 Min     47379
# 16-30 Min    11448
# 30+ Min       2647
# 2                1
# Name: stop_duration, dtype: int64

# %%
police['stop_duration'] = police['stop_duration'].map({ '0-15 Min' : 7.5 , '16-30 Min' : 24 , '30+ Min' : 45})

# %%
police
# Out:
#        stop_date    stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005   1:55:00 AM             M          1985.0        20.0
# 1      1/18/2005   8:15:00 AM             M          1965.0        40.0
# 2      1/23/2005  11:15:00 PM             M          1972.0        33.0
# 3      2/20/2005   5:15:00 PM             M          1986.0        19.0
# 4      3/14/2005  10:00:00 AM             F          1984.0        21.0
# ...          ...          ...           ...             ...         ...
# 65529  12/6/2012   5:54:00 PM             F          1987.0        25.0
# 65530  12/6/2012  10:22:00 PM             M          1954.0        58.0
# 65531  12/6/2012  11:20:00 PM             M          1985.0        27.0
# 65532  12/7/2012  12:23:00 AM           NaN             NaN         NaN
# 65533  12/7/2012  12:30:00 AM             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# 1           White                        Speeding   Speeding
# 2           White                        Speeding   Speeding
# 3           White                Call for Service      Other
# 4           White                        Speeding   Speeding
# ...           ...                             ...        ...
# 65529       White                        Speeding   Speeding
# 65530       White                        Speeding   Speeding
# 65531       Black  Equipment/Inspection Violation  Equipment
# 65532         NaN                             NaN        NaN
# 65533       White                        Speeding   Speeding
#
#        search_conducted search_type   stop_outcome is_arrested  stop_duration  \
# 0                 False         NaN       Citation       False            7.5
# 1                 False         NaN       Citation       False            7.5
# 2                 False         NaN       Citation       False            7.5
# 3                 False         NaN  Arrest Driver        True           24.0
# 4                 False         NaN       Citation       False            7.5
# ...                 ...         ...            ...         ...            ...
# 65529             False         NaN       Citation       False            7.5
# 65530             False         NaN        Warning       False            7.5
# 65531             False         NaN       Citation       False            7.5
# 65532             False         NaN            NaN         NaN            NaN
# 65533             False         NaN       Citation       False            7.5
#
#        drugs_related_stop
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 65529               False
# 65530               False
# 65531               False
# 65532               False
# 65533               False
#
# [65534 rows x 14 columns]

# %%
police['stop_duration'].mean()
# Out:
# 12.187420698181345

# %%
police.describe()
# Out:
#        driver_age_raw    driver_age  stop_duration
# count    61481.000000  61228.000000   61474.000000
# mean      1967.791106     34.148984      12.187421
# std        121.050106     12.760710       9.448853
# min          0.000000     15.000000       7.500000
# 25%       1965.000000     23.000000       7.500000
# 50%       1978.000000     31.000000       7.500000
# 75%       1985.000000     43.000000       7.500000
# max       8801.000000     88.000000      45.000000

# %%
df.head()
# Out:
#    stop_date    stop_time  country_name driver_gender  driver_age_raw  \
# 0   1/2/2005   1:55:00 AM           NaN             M          1985.0
# 1  1/18/2005   8:15:00 AM           NaN             M          1965.0
# 2  1/23/2005  11:15:00 PM           NaN             M          1972.0
# 3  2/20/2005   5:15:00 PM           NaN             M          1986.0
# 4  3/14/2005  10:00:00 AM           NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# 0         NaN       Citation       False      0-15 Min               False
# 1         NaN       Citation       False      0-15 Min               False
# 2         NaN       Citation       False      0-15 Min               False
# 3         NaN  Arrest Driver        True     16-30 Min               False
# 4         NaN       Citation       False      0-15 Min               False

# %%
df.groupby('violation').driver_age.describe()
# Out:
#                        count       mean        std   min   25%   50%   75%  \
# violation
# Equipment             6507.0  31.682957  11.380671  16.0  23.0  28.0  39.0
# Moving violation     11876.0  36.736443  13.258350  15.0  25.0  35.0  47.0
# Other                 3477.0  40.362381  12.754423  16.0  30.0  41.0  50.0
# Registration/plates   2240.0  32.656696  11.150780  16.0  24.0  30.0  40.0
# Seat belt                3.0  30.333333  10.214369  23.0  24.5  26.0  34.0
# Speeding             37120.0  33.262581  12.615781  15.0  23.0  30.0  42.0
#
#                       max
# violation
# Equipment            81.0
# Moving violation     86.0
# Other                86.0
# Registration/plates  74.0
# Seat belt            42.0
# Speeding             88.0
